# %% [markdown]
# <a href="https://colab.research.google.com/github/subhashigupta01/Sleep-Health-And-Lifestyle-Analysis-with-PYTHON/blob/main/Sleep_health_and_lifestyle_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries and import dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from google.colab import files
f = files.upload()
# Out:
#      <input type="file" id="files-e4c7c848-9929-4247-ad38-108ade19aa9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4c7c848-9929-4247-ad38-108ade19aa9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# data contain 374 rows and 13 columns
df = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv", index_col= "Person ID")
df
# Out:
#            Gender  Age            Occupation  Sleep Duration  \
# Person ID
# 1            Male   27     Software Engineer             6.1
# 2            Male   28                Doctor             6.2
# 3            Male   28                Doctor             6.2
# 4            Male   28  Sales Representative             5.9
# 5            Male   28  Sales Representative             5.9
# ...           ...  ...                   ...             ...
# 370        Female   59                 Nurse             8.1
# 371        Female   59                 Nurse             8.0
# 372        Female   59                 Nurse             8.1
# 373        Female   59                 Nurse             8.1
# 374        Female   59                 Nurse             8.1
#
#            Quality of Sleep  Physical Activity Level  Stress Level  \
# Person ID
# 1                         6                       42             6
# 2                         6                       60             8
# ...

# %% [markdown]
# **Data Description**
#
# The Sleep Health and Lifestyle Dataset has 400 rows and 13 columns, covering a wide range of variables related to sleep and daily habits. It includes details such as gender, age, occupation, sleep duration, quality of sleep, physical activity level, stress levels, BMI category, blood pressure, heart rate, daily steps, and the presence or absence of sleep disorders.
#
#     Person ID: An identifier for each individual.
#     Gender: The gender of the person (Male/Female).
#     Age: The age of the person in years.
#     Occupation: The occupation or profession of the person.
#     Sleep Duration (hours): The number of hours the person sleeps per day.
#     Quality of Sleep (scale: 1-10): A subjective rating of the quality of sleep, ranging from 1 to 10.
#     Physical Activity Level (minutes/day): The number of minutes the person engages in physical activity daily.
#     Stress Level (scale: 1-10): A subjective rating of the stress level experienced by the person, ranging from 1 to 10.
#     BMI Category: The BMI category of the person (e.g., Underweight, Normal, Overweight).
#     Blood Pressure (systolic/diastolic): The blood pressure measurement of the person, indicated as systolic pressure over diastolic pressure.
#     Heart Rate (bpm): The resting heart rate of the person in beats per minute.
#     Daily Steps: The number of steps the person takes per day.
#     Sleep Disorder: The presence or absence of a sleep disorder in the person (None, Insomnia, Sleep Apnea).

# %%
# checking number of rows from the top
df.head()
# Out:
#           Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 1           Male   27     Software Engineer             6.1                 6
# 2           Male   28                Doctor             6.2                 6
# 3           Male   28                Doctor             6.2                 6
# 4           Male   28  Sales Representative             5.9                 4
# 5           Male   28  Sales Representative             5.9                 4
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# 1                               42             6   Overweight         126/83
# 2                               60             8       Normal         125/80
# 3                               60             8       Normal         125/80
# 4                               30             8        Obese         140/90
# 5                               30             8        Obese         140/90
#
# ...

# %%
# checking number of rows from the bottom
df.tail()
# Out:
#            Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# Person ID
# 370        Female   59      Nurse             8.1                 9
# 371        Female   59      Nurse             8.0                 9
# 372        Female   59      Nurse             8.1                 9
# 373        Female   59      Nurse             8.1                 9
# 374        Female   59      Nurse             8.1                 9
#
#            Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# Person ID
# 370                             75             3   Overweight         140/95
# 371                             75             3   Overweight         140/95
# 372                             75             3   Overweight         140/95
# 373                             75             3   Overweight         140/95
# 374                             75             3   Overweight         140/95
#
#            Heart Rate  Daily Steps Sleep Disorder
# Person ID
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374 entries, 1 to 374
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    object
#  1   Age                      374 non-null    int64
#  2   Occupation               374 non-null    object
#  3   Sleep Duration           374 non-null    float64
#  4   Quality of Sleep         374 non-null    int64
#  5   Physical Activity Level  374 non-null    int64
#  6   Stress Level             374 non-null    int64
#  7   BMI Category             374 non-null    object
#  8   Blood Pressure           374 non-null    object
#  9   Heart Rate               374 non-null    int64
#  10  Daily Steps              374 non-null    int64
#  11  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 38.0+ KB

# %%
df["Sleep Disorder"].value_counts()
# Out:
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
#People with null values under Sleep Disorder it might be mean they don't have any sleep disorder,
#So I will replace the Null values with None
df["Sleep Disorder"].fillna("None", inplace= True)

# %%
# fill value in none
df["Sleep Disorder"].value_counts()
# Out:
# None           219
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
df["BMI Category"].value_counts()
# Out:
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: BMI Category, dtype: int64

# %%
# I am replacing normal with normal weight because both mean are same
df["BMI Category"].replace("Normal", "Normal Weight", inplace= True)

# %%
# check it replaced
df["BMI Category"].value_counts()
# Out:
# Normal Weight    216
# Overweight       148
# Obese             10
# Name: BMI Category, dtype: int64

# %% [markdown]
# **EDA**

# %% [markdown]
# Effect of Age on sleep Disorder

# %%
df.Age.describe()
# Out:
# count    374.000000
# mean      42.184492
# std        8.673133
# min       27.000000
# 25%       35.250000
# 50%       43.000000
# 75%       50.000000
# max       59.000000
# Name: Age, dtype: float64

# %%
sns.histplot(data=df, x="Age", hue="Sleep Disorder", multiple="stack", bins=np.arange(25,65,5) )
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# As per histogram Insomnia range the most between the ages 40-45.
#
#  Apnea occuring the most in the age range 50-60

# %% [markdown]
# How does sleep duration very with occupation?

# %%
df.Occupation.value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
#As we do not have enough samples for some occupations, we will find this relationship for a subset of occupation
plt.figure(figsize = (10,4))
df1= df.loc[df.Occupation.isin(["Nurse", "Doctor", "Engineer", "Lawyer", "Teacher", "Accountant", "Salesperson"])]
df1
sns.barplot(data= df1, y= "Occupation", x="Sleep Duration", palette=("rocket"))
# Out:
# <ipython-input-77-746422917f5c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= df1, y= "Occupation", x="Sleep Duration", palette=("rocket"))
# <Axes: xlabel='Sleep Duration', ylabel='Occupation'>

# %% [markdown]
# Engineer and lawyer sleep the most
#
# Teacher and salesperson sleep the least.

# %% [markdown]
# **Checking which occupation has which one sleep disorder**

# %%
plt.figure(figsize = (10,5))
sns.swarmplot(data= df, y= "Occupation", x= "Sleep Disorder", size = 2)
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Occupation'>

# %% [markdown]
# Occupation wise sleep disorder:
#
#     * Insomnia: Teachers,Salesperson
#     * Apnea: Nurse
#     * No Disorder: Lawyer,Doctor,Engineer,Accountant

# %% [markdown]
# **Which Sleep Disorder occurs the most within different Genders?**

# %%
df.Gender.value_counts()
# Out:
# Male      189
# Female    185
# Name: Gender, dtype: int64

# %%
# grouping genders by male and female
df.groupby('Gender')['Sleep Disorder'].value_counts()
# Out:
# Gender  Sleep Disorder
# Female  None               82
#         Sleep Apnea        67
#         Insomnia           36
# Male    None              137
#         Insomnia           41
#         Sleep Apnea        11
# Name: Sleep Disorder, dtype: int64

# %%
plt.title('Sleep disorder distribution by gender')
sns.histplot(data= df, x='Sleep Disorder', hue='Gender', multiple='stack', palette=("Set1"))
# Out:
# <Axes: title={'center': 'Sleep disorder distribution by gender'}, xlabel='Sleep Disorder', ylabel='Count'>

# %% [markdown]
# Females are more likely to have Apnea than men.
#
# Insomnia are equally distributed in both genders.

# %% [markdown]
# **1.BMI Category**

# %%
sns.histplot(data=df, x='BMI Category', hue='Sleep Disorder', multiple='stack')
# Out:
# <Axes: xlabel='BMI Category', ylabel='Count'>

# %% [markdown]
# 2. **Physical Activity Level**

# %%
plt.figure(figsize = (10,3))
sns.swarmplot(data= df, x= 'Sleep Disorder', y='Physical Activity Level', size=2)
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Physical Activity Level'>

# %% [markdown]
# Physical Activity Level of people with Apnea is more likely to be in the range 75 and 90.

# %% [markdown]
# Let's see if Physical Activity levels of Females mostly lie in this region too.

# %%
sns.swarmplot(x="Gender", y="Physical Activity Level", data=df, size = 2)
# Out:
# <Axes: xlabel='Gender', ylabel='Physical Activity Level'>

# %%
df.groupby('Gender')['Physical Activity Level'].mean()
# Out:
# Gender
# Female    59.140541
# Male      59.201058
# Name: Physical Activity Level, dtype: float64

# %% [markdown]
# From the above plot, Male and Female are equally lie in this range of Physical Activity. It means this might not be the factor causing sleep apnea in women more than men.

# %%
plt.figure(figsize=(10,4))
sns.histplot(data=df, x="Occupation", hue="Gender", multiple="stack")
plt.xticks(rotation=90);

# %% [markdown]
# As per the distribution of Occupations among Genders:
#
#    * All Nurses are Females. Among people with Apnea, most of them were nurses.
#
#    *  Among people with no sleep Disorders, most of them were Doctors and Lawyers, who are also most likely Male.

# %% [markdown]
# 4. **Age VS Sleeep Disorder**

# %%
plt.figure(figsize=(10,4))
sns.swarmplot(data=df, x="Sleep Disorder", y="Age",size=3, palette="Reds")
# Out:
# <ipython-input-84-fed197d4c586>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=df, x="Sleep Disorder", y="Age",size=3, palette="Reds")
# <Axes: xlabel='Sleep Disorder', ylabel='Age'>

# %%
sns.swarmplot(data=df, x="Gender", y="Age", size=2)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %% [markdown]
# There are no men over 50 years of age.
#  Apnea is more prevalent in the women who all are older than 40 years.

# %% [markdown]
# **Sleep duratioin VS Sleep Disorder**

# %%
df.groupby(["Gender", "Sleep Disorder"])["Sleep Duration"].mean()
# Out:
# Gender  Sleep Disorder
# Female  Insomnia          6.633333
#         None              7.650000
#         Sleep Apnea       7.035821
# Male    Insomnia          6.551220
#         None              7.183942
#         Sleep Apnea       7.009091
# Name: Sleep Duration, dtype: float64

# %%
df.groupby("Gender")["Sleep Duration"].mean()
# Out:
# Gender
# Female    7.229730
# Male      7.036508
# Name: Sleep Duration, dtype: float64

# %%
sns.barplot(x="Sleep Disorder", y="Sleep Duration", hue="Gender", data=df, palette=("Paired"))
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='Sleep Duration'>

# %% [markdown]
# ***In the given sleep disorder,the average sleep disorder doesn't vary much with the gender***.

# %% [markdown]
# **Relationship between Sleep Duration and Physical Activity Level**

# %%
sns.regplot(data=df, x= "Physical Activity Level",y="Sleep Duration", color="black")
# Out:
# <Axes: xlabel='Physical Activity Level', ylabel='Sleep Duration'>

# %%
plt.figure(figsize = (10,5))
sns.lmplot(data=df, x= "Physical Activity Level",y="Sleep Duration", hue="Sleep Disorder")

# %% [markdown]
# Physical Activity Level is positively correlated to Sleep Duration, however, for people with Apnea, the correlation is weakly negative.

# %% [markdown]
# **Let's check who is more stressed men or women?**

# %%
df.groupby("Gender")["Stress Level"].mean()
# Out:
# Gender
# Female    4.675676
# Male      6.079365
# Name: Stress Level, dtype: float64

# %%
plt.figure(figsize = (10,5))

sns.kdeplot(data=df, x= "Stress Level", hue= "Gender")
# Out:
# <Axes: xlabel='Stress Level', ylabel='Density'>

# %% [markdown]
# **Are younger people more stressed than the older lot?**

# %%
plt.figure(figsize = (10,4))


sns.regplot(data= df, x="Age", y="Stress Level", color="blue")
plt.xticks(rotation=75);

# %% [markdown]
# **Inferences and Conclusions**

# %% [markdown]
# The analysis of the dataset has revealed several noteworthy findings:
#
# **Age and Stress:** Younger individuals tend to experience higher levels of stress compared to their older counterparts. Additionally, men, on average, report higher stress levels than women. Surprisingly, there is no discernible correlation between stress levels and the presence of sleep disorders.
#
# **Physical Activity and Sleep:** The level of physical activity shows a positive correlation with sleep duration. However, for individuals with Apnea, higher physical activity is associated with shorter sleep duration.
#
# **Impact of Sleep Disorders:** Sleep disorders do not appear to significantly affect sleep duration differently among men and women.
#
# **Prevalence of Insomnia and Apnea:** Insomnia is most prevalent in the age range of 40-45, while Apnea occurs most frequently between the ages of 50-60.
#
# **Occupational Sleep Patterns:** Notably, Engineers and Lawyers exhibit the longest average sleep duration, while Teachers and Salespeople tend to sleep the least. Specific occupations with varying occurrences of sleep disorders include:
#
#     Insomnia: Teachers, Salespeople
#     Apnea: Nurses
#     No Disorder: Lawyers, Doctors, Engineers, Accountants
#
# Gender Disparities in Sleep Disorders:
#
#     Apnea is more prevalent among women.
#     Doctors and Lawyers, predominantly male occupations, show a higher occurrence of no sleep disorder.
#
# Apnea and Weight: A significant proportion of individuals with Apnea are overweight, particularly women. However, physical activity level alone may not explain the higher prevalence of Apnea in women compared to men.
#
# Occupational and Gender Distribution:
#
#     All Nurses are females, and most individuals with Apnea are nurses.
#     Among those with no sleep disorders, a majority are Doctors and Lawyers, who are predominantly male.
#     There are no men over 50 years of age, and Apnea is more prevalent among women older than 48
#
# These findings provide valuable insights into the complex interplay between age, gender, occupation, physical activity, and sleep patterns within the analyzed dataset.
